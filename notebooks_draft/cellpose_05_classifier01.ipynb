# %%
from platform import python_version
print(python_version())
# Out:
# 3.10.19

# %%
# !echo $CONDA_DEFAULT_ENV
# Out:
# cellpose_env

# %% [markdown]
# ### Install Cellpose-SAM
#
# https://pypi.org/project/cellpose/
#
# https://github.com/MouseLand/cellpose/blob/main/notebooks/run_Cellpose-SAM.ipynb

# %%
# !nvidia-smi
# Out:
# Tue Nov 18 18:07:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.133.07             Driver Version: 570.133.07     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...    Off |   00000000:01:00.0  On |                  N/A |
# | N/A   53C    P8              5W /   80W |    5573MiB /   6144MiB |     14%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1243      G   /usr/lib/xorg/Xorg                       61MiB |
# |    0   N/A  N/A            4167      C   .../envs/cellpose_env/bin/python       5394MiB |
# |    0   N/A  N/A           10086      C   .../envs/cellpose_env/bin/python         82MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Tue_May_27_02:21:03_PDT_2025
# Cuda compilation tools, release 12.9, V12.9.86
# Build cuda_12.9.r12.9/compiler.36037853_0

# %%
# !pip3 install scikit-learn
# !pip3 install seaborn
# !pip3 install plotly

# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(1, '../src/')

from Basic import *
from image_lib import *

# %% [markdown]
# #### Check if colab notebook instance has GPU access

# %%
is_laptop = True

if is_laptop:
    root0 = "../../colaboracoes/carlos_deOcesano"
else:
    root0 = "/media/flalix/d2f268d1-512d-499f-b3b3-6dad7d3fdd25/colaboracoes/deOcesano"
    
os.listdir(root0)
# Out:
# ['crop', 'tables', 'segment', 'samples']

# %%
cp = Cellpose(root0=root0, verbose=True)
# Out:
# No GPU access, change your runtime
# torch: 2.9.0+cu128
#
# ------- logger_setup() -----------
# 2025-11-18 18:07:42,094 [INFO] WRITING LOG OUTPUT TO /home/flalix/.cellpose/run.log
# 2025-11-18 18:07:42,095 [INFO]
# cellpose version: 	4.0.7
# platform:       	linux
# python version: 	3.10.19
# torch version:  	2.9.0+cu128
# (<Logger cellpose.io (INFO)>, PosixPath('/home/flalix/.cellpose/run.log'))
# 2025-11-18 18:07:42,095 [INFO] Neither TORCH CUDA nor MPS version not installed/working.

# %% [markdown]
# ### Plate: root_plate (images), root_tabel_image (dir dual)

# %%
plates = [x for x in os.listdir(cp.root_samples) if x.startswith('Plate')]
plates
# Out:
# ['Plate1848', 'Plate1847']

# %%
i=0
plate = plates[i]
cp.create_roots_plate(plate, verbose=True)

experiments = [x for x in os.listdir(cp.root_plate) if os.path.isdir( os.path.join(cp.root_plate, x) )]
experiments
# Out:
# >>> plate Plate1848 experiment is empty
# 	root_plate:      '../../colaboracoes/carlos_deOcesano/samples/Plate1848'
# 	root_tbl_plate:  '../../colaboracoes/carlos_deOcesano/tables/Plate1848'
# 	root_crop_plate: '../../colaboracoes/carlos_deOcesano/crop/Plate1848'
# 	root_seg_plate:  '../../colaboracoes/carlos_deOcesano/segment/Plate1848'
# ['1% SFB and IL-1B', '10% SFB', '1% SFB']

# %%
j=0
experiment=experiments[j]

cp.create_roots_experiment(experiment, verbose=True)
# Out:
# >>> experiment '1% SFB and IL-1B' - plate Plate1848
# 	root_tbl img/exp: '../../colaboracoes/carlos_deOcesano/tables/Plate1848/1% SFB and IL-1B'
# 	root image:       '../../colaboracoes/carlos_deOcesano/samples/Plate1848/1% SFB and IL-1B'
# 	root crop image:  '../../colaboracoes/carlos_deOcesano/crop/Plate1848'
# 	root seg image:   '../../colaboracoes/carlos_deOcesano/segment/Plate1848/1% SFB and IL-1B'

# %% [markdown]
# ### Image dirs

# %%
force=False
verbose=False

plates = [x for x in os.listdir(cp.root_samples) if x.startswith('Plate')]

for plate in plates:
    cp.create_roots_plate(plate, verbose=False)

    experiments = [x for x in os.listdir(cp.root_plate) if os.path.isdir( os.path.join(cp.root_plate, x) )]

    for experiment in experiments:
        cp.create_roots_experiment(experiment, verbose=False)

        files = cp.list_images(image_type='tif', verbose=False)

        print(f">>> plate {cp.plate} experiment {cp.experiment:25} has {len(files):3} images.")

        for fname in files:
            for ncrop in [5, 10, 20]:
                #_ = cp.crop_squares_already_set(fname, ncrop, force=force, verbose=verbose) 
                pass
# Out:
# >>> plate Plate1848 experiment 1% SFB and IL-1B          has  64 images.
# >>> plate Plate1848 experiment 10% SFB                   has  96 images.
# >>> plate Plate1848 experiment 1% SFB                    has  32 images.
# >>> plate Plate1847 experiment ATP5A1 - 1%SFB and IL-1B  has  48 images.
# >>> plate Plate1847 experiment P21 - 10%SFB              has  96 images.
# >>> plate Plate1847 experiment P21 - 1%SFB and IL-1B     has  48 images.
# >>> plate Plate1847 experiment exemplo                   has   3 images.
# >>> plate Plate1847 experiment ATP5A1 - 10%SFB           has  96 images.
# >>> plate Plate1847 experiment P21 - 1%SFB               has  48 images.
# >>> plate Plate1847 experiment ATP5A1 - 1%SFB            has  48 images.
