# %% [markdown]
# ### um pouco de mov. browninano - estatistica

# %%
import numpy as np

# %%
steps = [-3, -2, -1, 0, 1, 2, 3]

# %%
np.mean(steps)

# %%
np.std(steps)

# %% [markdown]
# ### Distribuição normal

# %%
random_numbers = np.random.rand(5)
random_numbers

# %% [markdown]
# ### Inteiros

# %%
np.random.randint(-5, 5, size=1)

# %%
np.random.choice([-1, 1])

# %%
lista = []
x = 0

N=10000

lista=[]
for i in range(N):
    ret = np.random.choice([-1, 1])
    if ret == 1:
        x+=1
    else:
        x+=-1

    lista.append(x)

np.abs(np.max(lista)) >=20, np.mean(lista), np.std(lista)

# %%
t = np.arange(N)

# %%
import matplotlib.pyplot as plt

# %%
lista = []
x = 0

N=1000

lista=[]
for i in range(N):
    ret = np.random.choice([-1, 1])
    if ret == 1:
        x+=1
    else:
        x+=-1

    lista.append(x)

t = np.arange(N)
print(np.max(np.abs(lista)) >=20, np.mean(lista), np.std(lista))

plt.figure(figsize=(8, 5))
plt.scatter(t, lista)  # scatter plot (no explicit color set)
plt.title("Random walk")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# ### Crescimento do desvio padrão

# %%
import pandas as pd

lista = []
x = 0

nloop=20
N = 0

dic={}; icount=-1

for i in range(nloop):
    N = N + 1000
    icount += 1

    lista=[]; x=0
    for i in range(N):
        ret = np.random.choice([-1, 1])
        if ret == 1:
            x+=1
        else:
            x-=1
    
        lista.append(x)

    mu = np.mean(lista)
    std = np.std(lista)

    dic[icount] = {}
    dic2 = dic[icount]
    # dic2['icount'] = icount
    dic2['N'] = N
    dic2['mu'] = mu
    dic2['std'] = std

df['mu'].mean(), df['mu'].std()

# %% [markdown]
# ### Como o randomico vira detministico

# %%
df = pd.DataFrame(dic).T
df
