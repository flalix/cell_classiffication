# %%
dic_plate = {}
dic_plate['Plate1847'] = {}
dic_plate['Plate1847']['class_names'] = ['10pct', '1pct', '1pct_il1b']
dic_plate['Plate1847']['dir_names'] = ['10perc', '1perc', 'IL1B']
dic_plate['Plate1847']['probes'] = ['ATP5A1', 'P21']
dic_plate['Plate1847']['dir_origins'] = ['%s - 10%%SFB', '%s - 1%%SFB', '%s - 1%%SFB and IL-1B']

dic_plate['Plate1848'] = {}
dic_plate['Plate1848']['class_names'] = ['10pct', '1pct', '1pct_il1b']
dic_plate['Plate1848']['dir_names'] = ['10perc', '1perc', 'IL1B']
dic_plate['Plate1848']['probes'] = ['FACT']
dic_plate['Plate1848']['dir_origins'] = ['%s - 10%%SFB', '%s - 1%%SFB', '%s - 1%%SFB and IL-1B']

dic_plate['Plate1849'] = {}
dic_plate['Plate1849']['class_names'] = ['10pct', '1pct', '1pct_il1b']
dic_plate['Plate1849']['dir_names'] = ['10perc', '1perc', 'IL1B']
dic_plate['Plate1849']['probes'] = ['FACT', 'Faloidina', 'MMP1']
dic_plate['Plate1849']['dir_origins'] = ['%s - 10%%SFB', '%s - 1%%SFB', '%s - 1%%SFB and IL-1B']

dic_plate['Plate1895'] = {}
dic_plate['Plate1895']['class_names'] = ['1pct', '1pct_il1b']
dic_plate['Plate1895']['dir_names'] = ['1perc', 'IL1B']
dic_plate['Plate1895']['probes'] = ['Bcatenin', 'Rab9']
dic_plate['Plate1895']['dir_origins'] = ['%s - 1%%SFB', '%s - 1%%SFB and IL-1B']

dic_plate['Plate1896'] = {}
dic_plate['Plate1896']['class_names'] = ['1pct', '1pct_il1b']
dic_plate['Plate1896']['dir_names'] = ['1perc', 'IL1B']
dic_plate['Plate1896']['probes'] = ['FACT', 'Faloidina', 'Rac1']
dic_plate['Plate1896']['dir_origins'] = ['%s - 1%%SFB', '%s - 1%%SFB and IL-1B']

# %%
dic_plate
