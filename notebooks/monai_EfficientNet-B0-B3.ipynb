# %%
# !python --version
# Out:
# Python 3.11.14

# %%
# !echo $CONDA_DEFAULT_ENV
# Out:
# cellpose_env

# %% [markdown]
# ## Monai wiht EfficientNet-B0/B3 (lightweight, great for cell morphology)
#
# ![BO](images/EfficientNet-Architecture-diagram.png)
#
# <br>
#
# ![B3](images/Architecture-of-EfficientNet-B0-with-MBConv-as-Basic-building-blocks.png)
#
#
# ### EfficientNet is lighter, faster, and more accurate than DenseNet for microscopy.
#
# | Model | Input Size | Parameters | Notes |
# |-------|-------|-------|-------|
# |B0 | 224×224 | 5.3M  | fast, small GPU |
# | B3 | 300×300 | 12M | higher accuracy for cellular phenotypes |

# %%
# !nvidia-smi
# Out:
# Mon Dec  1 12:44:11 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off |   00000000:01:00.0  On |                  N/A |
# |  0%   58C    P8             32W /  350W |    6683MiB /  24576MiB |     10%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1238      G   /usr/lib/xorg/Xorg                      176MiB |
# |    0   N/A  N/A            1883      G   cinnamon                                 43MiB |
# |    0   N/A  N/A            2178      G   ...rack-uuid=3190708988185955192         97MiB |
# |    0   N/A  N/A            4304      G   /usr/share/code/code                     44MiB |
# |    0   N/A  N/A           14485      C   ...s/cellpose_env/bin/python3.11       6004MiB |
# |    0   N/A  N/A           26224      C   ...s/cellpose_env/bin/python3.11        258MiB |
# +-----------------------------------------------------------------------------------------+

# %%
#!pip3 install opencv-python
#!pip3 instal monai tensorboard

# %%
import os, sys
import numpy as np
import pandas as pd

from glob import glob
from tqdm import tqdm

import matplotlib.pyplot as plt

sys.path.insert(1, '../src/')

from Basic import *
from image_lib import *

# %%
import torch
from torch.cuda.amp import autocast, GradScaler
from torch.optim import Adam

scaler = GradScaler()
torch.__version__
# Out:
# /tmp/ipykernel_31168/2058434058.py:5: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# '2.9.1+cu128'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3090'

# %%
import monai
monai.__version__
# Out:
# '1.5.1'

# %%
from monai.transforms.io.array import LoadImage
from monai.transforms.utility.array import EnsureChannelFirst, ToTensor
from monai.transforms.spatial.array import Resize, RandFlip, RandRotate, RandZoom
from monai.transforms.intensity.array import ScaleIntensity, RandGaussianNoise, RandShiftIntensity


from monai.data.dataloader import DataLoader as MonaiDataLoader # CacheDataset
# https://monai-dev.readthedocs.io/en/fixes-sphinx/networks.html
from monai.networks.nets import DenseNet121
from monai.losses import DiceCELoss
from monai.utils.misc import set_determinism
from monai.transforms.compose import Compose

# %%
set_determinism(42)

# %%
root0 = "../../colaboracoes/deOcesano/"
os.listdir(root0)
# Out:
# ['samples', 'segment', 'crop', 'train_and_test', 'tables']

# %%
cp = Cellpose(root0=root0, verbose=True)
# Out:
# torch: 2.9.1+cu128
#
# ------- logger_setup() -----------
# 2025-12-01 12:44:14,591 [INFO] WRITING LOG OUTPUT TO /home/flavio/.cellpose/run.log
# 2025-12-01 12:44:14,591 [INFO]
# cellpose version: 	4.0.7
# platform:       	linux
# python version: 	3.11.14
# torch version:  	2.9.1+cu128
# (<Logger cellpose.io (INFO)>, PosixPath('/home/flavio/.cellpose/run.log'))
# 2025-12-01 12:44:14,592 [INFO] ** TORCH CUDA version installed and working. **
#
# ------- GPU Ok -----------
# >> current_device: 0
# >> Device: NVIDIA GeForce RTX 3090
# >> CUDA: 12.8
#
# >> torch.version.cuda: 12.8
#
# Please set plate and experiment using create_roots(plate, experiment)

# %%
cp.set_default_parameters(root_yaml=os.getcwd(), verbose=True)
# Out:
# >> model_name   resnet18
# >> crop_segment crop
# >> dic_plate    5

# %%
cp.root_samples, cp.root_crop
# Out:
# ('../../colaboracoes/deOcesano/samples', '../../colaboracoes/deOcesano/crop')

# %%
plates = cp.list_plates(s_start='Plate')
plates
# Out:
# ['Plate1896', 'Plate1848', 'Plate1895', 'Plate1849', 'Plate1847']

# %%
i=0
plate=plates[i]

cp.set_plate_params(plate=plate, verbose=True)
# Out:
# >>> Plate1896 has probes: ['Faloidina', 'Rac1', 'FACT']
# >>> plate Plate1896 experiment must be set
# 	root_plate:	  '../../colaboracoes/deOcesano/samples/Plate1896'
# 	root_tbl_plate:  '../../colaboracoes/deOcesano/tables/Plate1896'
# 	root_crop_plate: '../../colaboracoes/deOcesano/crop/Plate1896'
# 	root_seg_plate:  '../../colaboracoes/deOcesano/segment/Plate1896'
#
# 	class_names 	 ['1pct', '1pct_il1b']
# 	probes 	 ['FACT', 'Faloidina', 'Rac1']
# 	dir_names 	 ['1perc', 'IL1B']
# 	dir_origins 	 []

# %%
cp.set_plate_params(plate=plate, verbose=False)

ncrop=5

for experiment in cp.experiments:
    cp.create_roots_experiment(experiment, verbose=False)
    fname_imgs = cp.list_crop_images_already_set(ncrop=ncrop, image_type='png', verbose=False)

    key = f"{plate} - {experiment}"
    print(key, len(fname_imgs), cp.root_crop_image)
# Out:
# >>> Plate1896 has probes: ['Faloidina', 'Rac1', 'FACT']
# Plate1896 - Faloidina - 1%SFB and IL-1B 1200 ../../colaboracoes/deOcesano/crop/Plate1896/Faloidina - 1%SFB and IL-1B
# Plate1896 - Rac1 - 1%SFB and IL-1B 1200 ../../colaboracoes/deOcesano/crop/Plate1896/Rac1 - 1%SFB and IL-1B
# Plate1896 - Rac1 - 1%SFB 1200 ../../colaboracoes/deOcesano/crop/Plate1896/Rac1 - 1%SFB
# Plate1896 - Faloidina - 1%SFB 1200 ../../colaboracoes/deOcesano/crop/Plate1896/Faloidina - 1%SFB
# Plate1896 - FACT - 1%SFB and IL-1B 1200 ../../colaboracoes/deOcesano/crop/Plate1896/FACT - 1%SFB and IL-1B
# Plate1896 - FACT - 1%SFB 1200 ../../colaboracoes/deOcesano/crop/Plate1896/FACT - 1%SFB

# %%
filename = os.path.join(cp.root_crop_image, fname_imgs[0])
os.path.exists(filename), filename
# Out:
# (True,
#  '../../colaboracoes/deOcesano/crop/Plate1896/FACT - 1%SFB/Overlay_D05_site_6.tif_crop_5_ncrop_5.png')

# %% [markdown]
# ### Create dataset dictionary list

# %%
def create_train_and_test_dataset(ncrop:int=5, perc:float=0.6, sel_probes:list=[]):
    dic = {}
    train_list, test_list = [], []
    plates = cp.list_plates(s_start='Plate')

    if perc < 0.2 or perc > .8:
        perc = 0.6

    classes = []
    for plate in plates:
        cp.set_plate_params(plate=plate, verbose=False)

        for experiment in cp.experiments:
            
            mat = experiment.split(' - ')
            probe = mat[0]
            perturb = mat[1]

            if len(sel_probes) > 0 and probe not in sel_probes:
                continue
                
            classes.append(experiment)

    classes = np.unique(classes)
    class_to_index = {_class: i for i, _class in enumerate(classes)}

    icount=-1
    for plate in plates:
        cp.set_plate_params(plate=plate, verbose=False)

        for experiment in cp.experiments:

            mat = experiment.split(' - ')
            probe = mat[0]
            perturb = mat[1]

            if len(sel_probes) > 0 and probe not in sel_probes:
                continue

            cp.create_roots_experiment(experiment, verbose=False)
            fname_imgs = cp.list_crop_images_already_set(ncrop=ncrop, image_type='png', verbose=False)
            fname_imgs = np.array(fname_imgs)

            n = len(fname_imgs)
            lista = np.arange(0, n)
            random.shuffle(lista)
            n_pick = int(n*perc)

            if perc <= 0.30:
                fname_imgs_train = fname_imgs[lista[:n_pick]]
                fname_imgs_test  = fname_imgs[lista[-n_pick:]]
            else:
                fname_imgs_train = fname_imgs[lista[:n_pick]]
                fname_imgs_test  = fname_imgs[lista[n_pick:]]

            key = f"{plate} - {experiment}"
            icount += 1
            dic[icount] = {}
            dic2 = dic[icount]
            dic2['plate_exp'] = key
            dic2['plate'] = plate
            dic2['experiment'] = experiment

            dic2['probe'] = probe
            dic2['perturb'] = perturb
            
            dic2['n'] = len(fname_imgs)
            dic2['n_train'] = len(fname_imgs_train)
            dic2['n_test']  = len(fname_imgs_test)
            dic2['root'] = cp.root_crop_image
            
            for fname in fname_imgs_train:
                train_list.append({"img": os.path.join(cp.root_crop_image, fname), "label": class_to_index[experiment] })

            for fname in fname_imgs_test:
                test_list.append({"img": os.path.join(cp.root_crop_image, fname), "label": class_to_index[experiment] })
                
    df = pd.DataFrame(dic).T
    df = df.sort_values(['probe', 'perturb', 'plate'])
    df = df.reset_index()
    
    return train_list, test_list, classes, df,  class_to_index

# %%
train_list, test_list, classes, dft, class_to_index = create_train_and_test_dataset(ncrop=5, perc=0.6, sel_probes=[])
print(len(dft))
">>> plate_exp_dic", len(dft), len(train_list), ' - first item', train_list[0]
# Out:
# >>> Plate1896 has probes: ['Faloidina', 'Rac1', 'FACT']
# >>> Plate1848 has probes: ['FACT']
# >>> Plate1895 has probes: ['Bcatenin', 'Rab9']
# >>> Plate1849 has probes: ['Faloidina', 'FACT', 'MMP1']
# >>> Plate1847 has probes: ['P21', 'ATP5A1']
# >>> Plate1896 has probes: ['Faloidina', 'Rac1', 'FACT']
# >>> Plate1848 has probes: ['FACT']
# >>> Plate1895 has probes: ['Bcatenin', 'Rab9']
# >>> Plate1849 has probes: ['Faloidina', 'FACT', 'MMP1']
# >>> Plate1847 has probes: ['P21', 'ATP5A1']
# 28
# ('>>> plate_exp_dic',
#  28,
#  24450,
#  ' - first item',
#  {'img': '../../colaboracoes/deOcesano/crop/Plate1896/Faloidina - 1%SFB and IL-1B/Overlay_H05_site_14.tif_crop_12_ncrop_5.png',
#   'label': 9})

# %%
filename = '../../colaboracoes/deOcesano/crop/Plate1848/FACT - 10%SFB/Overlay_B08_site_11.tif_crop_0_ncrop_5.png'
os.path.exists(filename)
# Out:
# True

# %%
print(len(dft))
dft
# Out:
# 28
#     index                                plate_exp      plate  \
# 0      25               Plate1847 - ATP5A1 - 1%SFB  Plate1847
# 1      24     Plate1847 - ATP5A1 - 1%SFB and IL-1B  Plate1847
# 2      27              Plate1847 - ATP5A1 - 10%SFB  Plate1847
# 3       9             Plate1895 - Bcatenin - 1%SFB  Plate1895
# 4      10   Plate1895 - Bcatenin - 1%SFB and IL-1B  Plate1895
# 5       7                 Plate1848 - FACT - 1%SFB  Plate1848
# 6      18                 Plate1849 - FACT - 1%SFB  Plate1849
# 7       5                 Plate1896 - FACT - 1%SFB  Plate1896
# 8       6       Plate1848 - FACT - 1%SFB and IL-1B  Plate1848
# 9      16       Plate1849 - FACT - 1%SFB and IL-1B  Plate1849
# 10      4       Plate1896 - FACT - 1%SFB and IL-1B  Plate1896
# 11      8                Plate1848 - FACT - 10%SFB  Plate1848
# 12     20                Plate1849 - FACT - 10%SFB  Plate1849
# 13     15            Plate1849 - Faloidina - 1%SFB  Plate1849
# 14      3            Plate1896 - Faloidina - 1%SFB  Plate1896
# 15     13  Plate1849 - Faloidina - 1%SFB and IL-1B  Plate1849
# 16      0  Plate1896 - Faloidina - 1%SFB and IL-1B  Plate1896
# 17     14           Plate1849 - Faloidina - 10%SFB  Plate1849
# 18     17                 Plate1849 - MMP1 - 1%SFB  Plate1849
# 19     21       Plate1849 - MMP1 - 1%SFB and IL-1B  Plate1849
# 20     19                Plate1849 - MMP1 - 10%SFB  Plate1849
# 21     23                  Plate1847 - P21 - 1%SFB  Plate1847
# 22     26        Plate1847 - P21 - 1%SFB and IL-1B  Plate1847
# 23     22                 Plate1847 - P21 - 10%SFB  Plate1847
# 24     11                 Plate1895 - Rab9 - 1%SFB  Plate1895
# 25     12       Plate1895 - Rab9 - 1%SFB and IL-1B  Plate1895
# 26      2                 Plate1896 - Rac1 - 1%SFB  Plate1896
# 27      1       Plate1896 - Rac1 - 1%SFB and IL-1B  Plate1896
#
#                      experiment      probe          perturb     n n_train  \
# 0                ATP5A1 - 1%SFB     ATP5A1            1%SFB  1200     720
# 1      ATP5A1 - 1%SFB and IL-1B     ATP5A1  1%SFB and IL-1B  1200     720
# 2               ATP5A1 - 10%SFB     ATP5A1           10%SFB  2400    1440
# 3              Bcatenin - 1%SFB   Bcatenin            1%SFB  1200     720
# 4    Bcatenin - 1%SFB and IL-1B   Bcatenin  1%SFB and IL-1B  1200     720
# 5                  FACT - 1%SFB       FACT            1%SFB   800     480
# 6                  FACT - 1%SFB       FACT            1%SFB  1200     720
# 7                  FACT - 1%SFB       FACT            1%SFB  1200     720
# 8        FACT - 1%SFB and IL-1B       FACT  1%SFB and IL-1B  1600     960
# 9        FACT - 1%SFB and IL-1B       FACT  1%SFB and IL-1B  1200     720
# 10       FACT - 1%SFB and IL-1B       FACT  1%SFB and IL-1B  1200     720
# 11                FACT - 10%SFB       FACT           10%SFB  2400    1440
# 12                FACT - 10%SFB       FACT           10%SFB  2400    1440
# 13            Faloidina - 1%SFB  Faloidina            1%SFB  1200     720
# 14            Faloidina - 1%SFB  Faloidina            1%SFB  1200     720
# 15  Faloidina - 1%SFB and IL-1B  Faloidina  1%SFB and IL-1B  1200     720
# 16  Faloidina - 1%SFB and IL-1B  Faloidina  1%SFB and IL-1B  1200     720
# 17           Faloidina - 10%SFB  Faloidina           10%SFB  2400    1440
# 18                 MMP1 - 1%SFB       MMP1            1%SFB  1200     720
# 19       MMP1 - 1%SFB and IL-1B       MMP1  1%SFB and IL-1B  1150     690
# 20                MMP1 - 10%SFB       MMP1           10%SFB  2400    1440
# 21                  P21 - 1%SFB        P21            1%SFB  1200     720
# 22        P21 - 1%SFB and IL-1B        P21  1%SFB and IL-1B  1200     720
# 23                 P21 - 10%SFB        P21           10%SFB  2400    1440
# 24                 Rab9 - 1%SFB       Rab9            1%SFB  1200     720
# 25       Rab9 - 1%SFB and IL-1B       Rab9  1%SFB and IL-1B  1200     720
# 26                 Rac1 - 1%SFB       Rac1            1%SFB  1200     720
# 27       Rac1 - 1%SFB and IL-1B       Rac1  1%SFB and IL-1B  1200     720
#
#    n_test                                               root
# 0     480  ../../colaboracoes/deOcesano/crop/Plate1847/AT...
# 1     480  ../../colaboracoes/deOcesano/crop/Plate1847/AT...
# 2     960  ../../colaboracoes/deOcesano/crop/Plate1847/AT...
# 3     480  ../../colaboracoes/deOcesano/crop/Plate1895/Bc...
# 4     480  ../../colaboracoes/deOcesano/crop/Plate1895/Bc...
# 5     320  ../../colaboracoes/deOcesano/crop/Plate1848/FA...
# 6     480  ../../colaboracoes/deOcesano/crop/Plate1849/FA...
# 7     480  ../../colaboracoes/deOcesano/crop/Plate1896/FA...
# 8     640  ../../colaboracoes/deOcesano/crop/Plate1848/FA...
# 9     480  ../../colaboracoes/deOcesano/crop/Plate1849/FA...
# 10    480  ../../colaboracoes/deOcesano/crop/Plate1896/FA...
# 11    960  ../../colaboracoes/deOcesano/crop/Plate1848/FA...
# 12    960  ../../colaboracoes/deOcesano/crop/Plate1849/FA...
# 13    480  ../../colaboracoes/deOcesano/crop/Plate1849/Fa...
# 14    480  ../../colaboracoes/deOcesano/crop/Plate1896/Fa...
# 15    480  ../../colaboracoes/deOcesano/crop/Plate1849/Fa...
# 16    480  ../../colaboracoes/deOcesano/crop/Plate1896/Fa...
# 17    960  ../../colaboracoes/deOcesano/crop/Plate1849/Fa...
# 18    480  ../../colaboracoes/deOcesano/crop/Plate1849/MM...
# 19    460  ../../colaboracoes/deOcesano/crop/Plate1849/MM...
# 20    960  ../../colaboracoes/deOcesano/crop/Plate1849/MM...
# 21    480  ../../colaboracoes/deOcesano/crop/Plate1847/P2...
# 22    480  ../../colaboracoes/deOcesano/crop/Plate1847/P2...
# 23    960  ../../colaboracoes/deOcesano/crop/Plate1847/P2...
# 24    480  ../../colaboracoes/deOcesano/crop/Plate1895/Ra...
# 25    480  ../../colaboracoes/deOcesano/crop/Plate1895/Ra...
# 26    480  ../../colaboracoes/deOcesano/crop/Plate1896/Ra...
# 27    480  ../../colaboracoes/deOcesano/crop/Plate1896/Ra...

# %%
class_to_index
# Out:
# {'ATP5A1 - 1%SFB': 0,
#  'ATP5A1 - 1%SFB and IL-1B': 1,
#  'ATP5A1 - 10%SFB': 2,
#  'Bcatenin - 1%SFB': 3,
#  'Bcatenin - 1%SFB and IL-1B': 4,
#  'FACT - 1%SFB': 5,
#  'FACT - 1%SFB and IL-1B': 6,
#  'FACT - 10%SFB': 7,
#  'Faloidina - 1%SFB': 8,
#  'Faloidina - 1%SFB and IL-1B': 9,
#  'Faloidina - 10%SFB': 10,
#  'MMP1 - 1%SFB': 11,
#  'MMP1 - 1%SFB and IL-1B': 12,
#  'MMP1 - 10%SFB': 13,
#  'P21 - 1%SFB': 14,
#  'P21 - 1%SFB and IL-1B': 15,
#  'P21 - 10%SFB': 16,
#  'Rab9 - 1%SFB': 17,
#  'Rab9 - 1%SFB and IL-1B': 18,
#  'Rac1 - 1%SFB': 19,
#  'Rac1 - 1%SFB and IL-1B': 20}

# %%
len(classes), classes
# Out:
# (21,
#  array(['ATP5A1 - 1%SFB', 'ATP5A1 - 1%SFB and IL-1B', 'ATP5A1 - 10%SFB',
#         'Bcatenin - 1%SFB', 'Bcatenin - 1%SFB and IL-1B', 'FACT - 1%SFB',
#         'FACT - 1%SFB and IL-1B', 'FACT - 10%SFB', 'Faloidina - 1%SFB',
#         'Faloidina - 1%SFB and IL-1B', 'Faloidina - 10%SFB',
#         'MMP1 - 1%SFB', 'MMP1 - 1%SFB and IL-1B', 'MMP1 - 10%SFB',
#         'P21 - 1%SFB', 'P21 - 1%SFB and IL-1B', 'P21 - 10%SFB',
#         'Rab9 - 1%SFB', 'Rab9 - 1%SFB and IL-1B', 'Rac1 - 1%SFB',
#         'Rac1 - 1%SFB and IL-1B'], dtype='<U27'))

# %%
train_list[:2]
# Out:
# [{'img': '../../colaboracoes/deOcesano/crop/Plate1896/Faloidina - 1%SFB and IL-1B/Overlay_H05_site_14.tif_crop_12_ncrop_5.png',
#   'label': 9},
#  {'img': '../../colaboracoes/deOcesano/crop/Plate1896/Faloidina - 1%SFB and IL-1B/Overlay_H06_site_11.tif_crop_22_ncrop_5.png',
#   'label': 9}]

# %% [markdown]
# ### Transforms for B0 or B3 - EfficientNet-B3 (300×300)

# %%
# from monai.transforms import RandGaussianNoise, RandZoom, RandShiftIntensity

train_transforms = [
    LoadImage(image_only=True),
    EnsureChannelFirst(),
    Resize((300, 300)),
    RandFlip(prob=0.5),
    RandRotate(range_x=0.2, prob=0.5),
    RandZoom(min_zoom=0.9, max_zoom=1.1, prob=0.3),
    RandGaussianNoise(prob=0.2),
    ScaleIntensity(),
    ToTensor()
]

# %%
def apply_transforms(sample):
    img = sample["img"]
    label = sample["label"]
    for train_transf_method in train_transforms:
        img = train_transf_method(img)
    return img, torch.tensor(label, dtype=torch.long)

# %% [markdown]
# ### Dataset + Loader

# %%
def evaluate_loss_accuracy(model, loader):
    model.eval()
    tot_accuracy = 0
    loss_sum = 0

    with torch.no_grad():
        for images, labels in loader:
            images = images.cuda()
            labels = labels.cuda()
        
            with autocast('cuda'):
                outputs = model(images)
                loss = criterion(outputs, labels)
                preds = outputs.argmax(1)

            loss_sum += loss.item()
            tot_accuracy += (preds == labels).mean().item()

    return loss_sum / len(loader), tot_accuracy / len(loader)

# %%
class CellDataset(torch.utils.data.Dataset):
    def __init__(self, items):
        self.items = items
    def __len__(self):
        return len(self.items)
    def __getitem__(self, idx):
        return apply_transforms(self.items[idx])

# %% [markdown]
# ### Build data

# %%
try:
    del(train_list)
    del(test_list)
except:
    pass

# %%
sel_probes = ['FACT', 'MMP1', 'Faloidina']
sel_probes = ['FACT']

train_list, test_list, classes, dft, class_to_index = create_train_and_test_dataset(ncrop=5, perc=0.40, sel_probes=sel_probes)
len(train_list), len(test_list), len(classes)
# Out:
# >>> Plate1896 has probes: ['Faloidina', 'Rac1', 'FACT']
# >>> Plate1848 has probes: ['FACT']
# >>> Plate1895 has probes: ['Bcatenin', 'Rab9']
# >>> Plate1849 has probes: ['Faloidina', 'FACT', 'MMP1']
# >>> Plate1847 has probes: ['P21', 'ATP5A1']
# >>> Plate1896 has probes: ['Faloidina', 'Rac1', 'FACT']
# >>> Plate1848 has probes: ['FACT']
# >>> Plate1895 has probes: ['Bcatenin', 'Rab9']
# >>> Plate1849 has probes: ['Faloidina', 'FACT', 'MMP1']
# >>> Plate1847 has probes: ['P21', 'ATP5A1']
# (4800, 7200, 3)

# %%
dft
# Out:
#    index                           plate_exp      plate  \
# 0      3            Plate1848 - FACT - 1%SFB  Plate1848
# 1      6            Plate1849 - FACT - 1%SFB  Plate1849
# 2      1            Plate1896 - FACT - 1%SFB  Plate1896
# 3      2  Plate1848 - FACT - 1%SFB and IL-1B  Plate1848
# 4      5  Plate1849 - FACT - 1%SFB and IL-1B  Plate1849
# 5      0  Plate1896 - FACT - 1%SFB and IL-1B  Plate1896
# 6      4           Plate1848 - FACT - 10%SFB  Plate1848
# 7      7           Plate1849 - FACT - 10%SFB  Plate1849
#
#                experiment probe          perturb     n n_train n_test  \
# 0            FACT - 1%SFB  FACT            1%SFB   800     320    480
# 1            FACT - 1%SFB  FACT            1%SFB  1200     480    720
# 2            FACT - 1%SFB  FACT            1%SFB  1200     480    720
# 3  FACT - 1%SFB and IL-1B  FACT  1%SFB and IL-1B  1600     640    960
# 4  FACT - 1%SFB and IL-1B  FACT  1%SFB and IL-1B  1200     480    720
# 5  FACT - 1%SFB and IL-1B  FACT  1%SFB and IL-1B  1200     480    720
# 6           FACT - 10%SFB  FACT           10%SFB  2400     960   1440
# 7           FACT - 10%SFB  FACT           10%SFB  2400     960   1440
#
#                                                 root
# 0  ../../colaboracoes/deOcesano/crop/Plate1848/FA...
# 1  ../../colaboracoes/deOcesano/crop/Plate1849/FA...
# 2  ../../colaboracoes/deOcesano/crop/Plate1896/FA...
# 3  ../../colaboracoes/deOcesano/crop/Plate1848/FA...
# 4  ../../colaboracoes/deOcesano/crop/Plate1849/FA...
# 5  ../../colaboracoes/deOcesano/crop/Plate1896/FA...
# 6  ../../colaboracoes/deOcesano/crop/Plate1848/FA...
# 7  ../../colaboracoes/deOcesano/crop/Plate1849/FA...

# %%
classes
# Out:
# array(['FACT - 1%SFB', 'FACT - 1%SFB and IL-1B', 'FACT - 10%SFB'],
#       dtype='<U22')

# %%
class_to_index
# Out:
# {'FACT - 1%SFB': 0, 'FACT - 1%SFB and IL-1B': 1, 'FACT - 10%SFB': 2}

# %% [markdown]
# ### Model (MONAI DenseNet) – good for biomedical images

# %%
lr=1e-4
weight_decay=1e-4

# %%
from monai.networks.nets.efficientnet import EfficientNetBN

model = EfficientNetBN(
    model_name="efficientnet-b3",
    spatial_dims=2,
    in_channels=3, 
    num_classes=len(classes),
    pretrained=True   # USE pretrained = better accuracy
).cuda()

# use Label Smoothing
criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.1)
# Try AdamW instead of Adam:
# optimizer = Adam(model.parameters(), lr=lr)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

# %% [markdown]
# ### Loader

# %%
ds_train = CellDataset(train_list)
train_loader = MonaiDataLoader(ds_train, batch_size=16, shuffle=True, num_workers=4)

ds_test = CellDataset(test_list)
test_loader = MonaiDataLoader(ds_test, batch_size=16, shuffle=True, num_workers=4)

# %%
train_losses, test_losses, accu_list = [], [], []

# %%
def get_model_name(sel_probes, ncrop):
    if sel_probes == []:
        fname_model = f"cell_EfficientNet_B3_{ncrop}.pt"
    else:
        fname_model = f"cell_EfficientNet_B3_{ncrop}_probes_{'_'.join(sel_probes)}.pt"
    
    filename = os.path.join(cp.root_samples, fname_model)
    return filename, fname_model

def save_model(model, optimizer, classes, class_to_index, sel_probes, ncrop, train_losses, test_losses, accu_list):

    filename, fname_model = get_model_name(sel_probes, ncrop)

    try:
        torch.save({
            "model_state": model.state_dict(),
            "optimizer_state": optimizer.state_dict(),
            "classes": classes,
            "class_to_index": class_to_index,
            "train_losses": train_losses,
            "test_losses": test_losses,
            "accu_list": accu_list,
            "n": len(accu_list),
        },  filename)
        print(f"File saved at '{filename}'")
        ret = True
    except:
        print(f"Error: could not save '{filename}'")
        ret = False

    return ret

def read_model(model, optimizer, sel_probes, ncrop):
    filename, fname_model = get_model_name(sel_probes, ncrop)

    if not os.path.exists(filename):
        return False, (model, [], [], [])
    
    new_model = model
    checkpoint = torch.load(filename, map_location="cuda", weights_only=False)

    new_model.load_state_dict(checkpoint["model_state"])
    optimizer.load_state_dict(checkpoint["optimizer_state"])

    train_losses = checkpoint["train_losses"]
    test_losses = checkpoint["test_losses"]
    accu_list = checkpoint["accu_list"]

    return True, (new_model, train_losses, test_losses, accu_list)


def plot_losses_and_accuracy(train_losses, test_losses, accu_list, figsize=(12,5)):
    epochs_range = range(1, len(train_losses) + 1)
    plt.figure(figsize=figsize)
    
    #------ loss plot ------------------
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, train_losses, marker='o', label='Train Loss')
    plt.plot(epochs_range, test_losses, marker='o', label='Test Loss')
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.title("Training & Test Losses")
    
    #----- accuracy plot ---------------
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, accu_list, marker='o', label='Test Accuracy')
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title("Test Accuracy")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# %%
filename, fname_model = get_model_name(sel_probes, ncrop)
filename, fname_model
# Out:
# ('../../colaboracoes/deOcesano/samples/cell_EfficientNet_B3_5_probes_FACT.pt',
#  'cell_EfficientNet_B3_5_probes_FACT.pt')

# %%
ret, (new_model, train_losses, test_losses, accu_list) = read_model(model, optimizer, sel_probes, ncrop)

# %%
if ret:
    print("Loading the saved model ...")
    model = new_model
else:
    print("Starting a new model ...")
# Out:
# Starting a new model ...

# %%
len(train_losses), train_losses
# Out:
# (0, [])

# %%
len(test_losses), test_losses
# Out:
# (0, [])

# %%
len(accu_list), accu_list
# Out:
# (0, [])

# %% [markdown]
# ### Use mixed precision (AMP)
#
# AMP gives faster training + better stability:

# %%
maxi=0

# %%
n_epochs = 10
n_epochs = 25
n_epochs = 15

n_count_repeat = 0
m_max_repeat = 10

for epoch in range(n_epochs):
    model.train()
    
    tot_train_loss = 0.0
    for imgs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{n_epochs}"):
        imgs = imgs.cuda()
        labels = labels.cuda()

        optimizer.zero_grad()

        # with autocast(device_type="cuda", enabled=True, dtype=torch.float16):
        with autocast():
            outputs = model(imgs)
            train_loss = criterion(outputs, labels)
        
        scaler.scale(train_loss).backward()
        scaler.step(optimizer)
        scaler.update()
        
        # train_loss.backward()
        # optimizer.step()
        tot_train_loss += train_loss.item()

    tot_test_loss = 0.0
    tot_accuracy = 0.
        
    with torch.no_grad(), autocast():
        for imgs, labels in test_loader:
            imgs = imgs.cuda()
            labels = labels.cuda()
    
            outputs = model(imgs)
            test_loss = criterion(outputs, labels)
    
            tot_test_loss += test_loss.item()
    
            best_pred = outputs.argmax(1)
            # Because .mean() gives the accuracy for the batch
            tot_accuracy += (best_pred == labels).float().mean().item()

    accuracy   = tot_accuracy   / len(test_loader)
    train_loss = tot_train_loss / len(train_loader)
    test_loss  = tot_test_loss  / len(test_loader)
    
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    accu_list.append(accuracy)

    print(f"Epoch {epoch+1} - accuracy: {accuracy*100:.1f}% loss train: {train_loss:.4f} test: {test_loss:.4f}")
    
    if accuracy > maxi:
        n_count_repeat = 0
        maxi = accuracy
        save_model(model, optimizer, classes, class_to_index, sel_probes, ncrop, train_losses, test_losses, accu_list)
    else:
        n_count_repeat +=1
        if n_count_repeat >= m_max_repeat:
            print("Warning: did not improve")
            break
        
print("-------- training complete ----------")
# Out:
# Epoch 1/15:   0%|                                                                                                                                          | 0/300 [00:00<?, ?it/s]/tmp/ipykernel_31168/2036160932.py:16: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:23<00:00, 12.56it/s]
# /tmp/ipykernel_31168/2036160932.py:31: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
# Epoch 1 - accuracy: 86.0% loss train: 0.3260 test: 0.5542
# Epoch 2/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:24<00:00, 12.19it/s]
# Epoch 2 - accuracy: 86.0% loss train: 0.3284 test: 0.5576
# Epoch 3/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:24<00:00, 12.30it/s]
# Epoch 3 - accuracy: 86.1% loss train: 0.3292 test: 0.5590
# Epoch 4/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:25<00:00, 11.96it/s]
# File saved at '../../colaboracoes/deOcesano/samples/cell_EfficientNet_B3_5_probes_FACT.pt'
# Epoch 4 - accuracy: 87.2% loss train: 0.3250 test: 0.5434
# Epoch 5/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:24<00:00, 12.10it/s]
# File saved at '../../colaboracoes/deOcesano/samples/cell_EfficientNet_B3_5_probes_FACT.pt'
# Epoch 5 - accuracy: 87.3% loss train: 0.3262 test: 0.5336
# Epoch 6/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:24<00:00, 12.10it/s]
# File saved at '../../colaboracoes/deOcesano/samples/cell_EfficientNet_B3_5_probes_FACT.pt'
# Epoch 6 - accuracy: 87.4% loss train: 0.3259 test: 0.5357
# Epoch 7/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:25<00:00, 11.65it/s]
# Epoch 7 - accuracy: 87.1% loss train: 0.3211 test: 0.5304
# Epoch 8/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:25<00:00, 11.84it/s]
# Epoch 8 - accuracy: 86.4% loss train: 0.3182 test: 0.5505
# Epoch 9/15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:24<00:00, 12.31it/s]
# Epoch 9 - accuracy: 87.2% loss train: 0.3166 test: 0.5338
# Epoch 10/15: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:25<00:00, 11.83it/s]
# Epoch 10 - accuracy: 87.1% loss train: 0.3174 test: 0.5353
# Epoch 11/15: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:24<00:00, 12.10it/s]
# Epoch 11 - accuracy: 87.0% loss train: 0.3187 test: 0.5349
# Epoch 12/15: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:25<00:00, 11.84it/s]
# Epoch 12 - accuracy: 85.7% loss train: 0.3184 test: 0.5650
# Epoch 13/15: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:25<00:00, 11.83it/s]
# Epoch 13 - accuracy: 87.4% loss train: 0.3205 test: 0.5292
# Epoch 14/15: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:25<00:00, 11.86it/s]
# File saved at '../../colaboracoes/deOcesano/samples/cell_EfficientNet_B3_5_probes_FACT.pt'
# Epoch 14 - accuracy: 87.7% loss train: 0.3154 test: 0.5291
# Epoch 15/15: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [00:25<00:00, 11.94it/s]
# Epoch 15 - accuracy: 87.1% loss train: 0.3169 test: 0.5351
# -------- training complete ----------

# %%
plot_losses_and_accuracy(train_losses, test_losses, accu_list, figsize=(12,5))

# %%
np.round(100*maxi,1)
# Out:
# 87.7
